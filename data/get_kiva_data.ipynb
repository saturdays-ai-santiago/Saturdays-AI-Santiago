# %% [markdown]
# Get Kiva data
# =====

# %%
reset -fs

# %%
import os
import json
import logging
import requests
import time
from urllib.request import urlopen, Request

from pandas.io.json import json_normalize
import pandas as pd

# %%
# # # Code for understanding KIVA api
# for code in [None]:
#     print(code)
#     url = f'http://api.kivaws.org/v1/loans/search.json?country_code={code}&per_page=5'
#     r = requests.get(url)
#     # r.status_code
#     print(r.json()['loans'][0])
#     break


# # Find number of pages
# url = f'http://api.kivaws.org/v1/loans/search.json?country_code={country_iso_code}'
# r = requests.get(url)
# data = json.loads(r.text)
# data

# %%
# Africian contry codes
country_codes_without_data = ["DZ", "AO", "SH", "CV", "CF", "TD", "KM", "DJ","GQ", "ER", "SZ",  "ET",  "GA", "GM", "GN",  "GW",    "LY",  "MU", "YT", "MA",  "NE",  "ST",  "RE", "ST",   "SC",  "SH", "SD","SZ","TN",  ]

country_codes_with_data = {"BJ", "BW", "BF", "BI", "CM", "CG", "CD", "EG", 
                           "GH", "CI", "KE", "LS", "LR", "MG", "MW", "ML", 
                           "MR", "MZ", "NA", "NG", "RW", "SN", "SL", "SO",
                           "ZA", "SS", "TZ", "TG", "UG", "ZM", "ZW"}

# %%
loans_complete = pd.DataFrame()
print("Requesting…")

for country_iso_code in country_codes_with_data: 
    print(f"Country: {country_iso_code}")
    n_pages = 10
    for page in range(1, n_pages+1):
        print(f"\t Page: {page}")
        url = f'http://api.kivaws.org/v1/loans/search.json?country_code={country_iso_code}&page={page}'
        r = requests.get(url)
        if r.status_code == 403:
            raise Exception("Too many requests. Slow down 🐢")
        
        data = json.loads(r.text)
        if (data['paging']['total'] == 0) or (not data['loans']):
            break # Stop if there are no loans
            
        loans = json_normalize(data['loans'])
        
        # Take the loan id column from our retrieved loan data
        # Use it to pull additional details about our loans.
        loan_ids = loans['id'].tolist()
        loan_ids_str = ','.join(str(e) for e in loan_ids)

        r = requests.get('https://api.kivaws.org/v1/loans/'+loan_ids_str+'.json')
        ld_data = json.loads(r.text)
        loans_ext = json_normalize(ld_data['loans'])

        # Join on two dataframes
        temp = pd.merge(loans, 
                         loans_ext, 
                         how='inner', 
                         on='id', 
                         sort=False,
                         left_on=None, right_on=None, left_index=False, right_index=False, 
                         suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
        loans_complete = loans_complete.append(temp)
        
        time.sleep(1.2) # Wait a little while to so we don't overload Kiva servers
# Out:
# Requesting…
# Country: BI
# 	 Page: 1
# 	 Page: 2
# 	 Page: 3
# 	 Page: 4
# 	 Page: 5
# 	 Page: 6
# 	 Page: 7
# 	 Page: 8
# C:\Users\Lina\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# 	 Page: 9
# 	 Page: 10
# Country: CM
# 	 Page: 1
# 	 Page: 2
# 	 Page: 3
# 	 Page: 4
# 	 Page: 5
# 	 Page: 6
# 	 Page: 7
# 	 Page: 8
# 	 Page: 9
# 	 Page: 10
# Country: SO
# 	 Page: 1
# 	 Page: 2
# 	 Page: 3
# 	 Page: 4
# 	 Page: 5
# 	 Page: 6
# 	 Page: 7
# 	 Page: 8
# 	 Page: 9
# 	 Page: 10
# Country: BF
# 	 Page: 1
# 	 Page: 2
# 	 Page: 3
# 	 Page: 4
# 	 Page: 5
# 	 Page: 6
# 18            NaN               NaN                NaN
# 19            NaN               NaN                NaN
#
# [2 rows x 82 columns]

# %%
cols = [column for column in loans_complete.columns.tolist() if '_y' not in column]
{col: col[0:len(col)-2] for col in cols if '_x' in col}
# Out:
# {'activity_x': 'activity',
#  'basket_amount_x': 'basket_amount',
#  'bonus_credit_eligibility_x': 'bonus_credit_eligibility',
#  'currency_exchange_loss_amount_x': 'currency_exchange_loss_amount',
#  'description_languages_x': 'description_languages',
#  'funded_amount_x': 'funded_amount',
#  'image_id_x': 'image_id',
#  'image_template_id_x': 'image_template_id',
#  'lender_count_x': 'lender_count',
#  'loan_amount_x': 'loan_amount',
#  'location_country_code_x': 'location_country_code',
#  'location_country_x': 'location_country',
#  'location_geo_level_x': 'location_geo_level',
#  'location_geo_pairs_x': 'location_geo_pairs',
#  'location_geo_type_x': 'location_geo_type',
#  'location_town_x': 'location_town',
#  'name_x': 'name',
#  'partner_id_x': 'partner_id',
#  'planned_expiration_date_x': 'planned_expiration_date',
#  'posted_date_x': 'posted_date',
#  'sector_x': 'sector',
#  'status_x': 'status',
#  'tags_x': 'tags',
#  'themes_x': 'themes',
#  'use_x': 'use',
#  'video_id_x': 'video_id',
#  'video_thumbnailImageId_x': 'video_thumbnailImageId',
#  'video_title_x': 'video_title'}

# %%
{col: col for col in cols if '_x' not in col}
# Out:
# {'borrower_count': 'borrower_count',
#  'borrowers': 'borrowers',
#  'description_texts_en': 'description_texts_en',
#  'description_texts_es': 'description_texts_es',
#  'description_texts_fr': 'description_texts_fr',
#  'description_texts_pt': 'description_texts_pt',
#  'funded_date': 'funded_date',
#  'id': 'id',
#  'journal_totals_bulkEntries': 'journal_totals_bulkEntries',
#  'journal_totals_entries': 'journal_totals_entries',
#  'payments': 'payments',
#  'terms_disbursal_amount': 'terms_disbursal_amount',
#  'terms_disbursal_currency': 'terms_disbursal_currency',
#  'terms_disbursal_date': 'terms_disbursal_date',
#  'terms_loan_amount': 'terms_loan_amount',
#  'terms_local_payments': 'terms_local_payments',
#  'terms_loss_liability_currency_exchange': 'terms_loss_liability_currency_exchange',
#  'terms_loss_liability_currency_exchange_coverage_rate': 'terms_loss_liability_currency_exchange_coverage_rate',
#  'terms_loss_liability_nonpayment': 'terms_loss_liability_nonpayment',
#  'terms_repayment_interval': 'terms_repayment_interval',
#  'terms_repayment_term': 'terms_repayment_term',
#  'terms_scheduled_payments': 'terms_scheduled_payments',
#  'translator_byline': 'translator_byline',
#  'translator_image': 'translator_image'}

# %%
# Select and reorder columns
selected_cols = ['activity_x',
     'basket_amount_x',
     'bonus_credit_eligibility_x',
     'borrower_count',
     'borrowers',
     'currency_exchange_loss_amount_x',
     'description_languages_x',
     'description_texts_en',
     'description_texts_es',
     'description_texts_fr',
     'description_texts_pt',
     'funded_amount_x',
     'funded_date',
     'id',
     'image_id_x',
     'image_template_id_x',
     'journal_totals_bulkEntries',
     'journal_totals_entries',
     'lender_count_x',
     'loan_amount_x',
     'location_country_code_x',
     'location_country_x',
     'location_geo_level_x',
     'location_geo_pairs_x',
     'location_geo_type_x',
     'location_town_x',
     'name_x',
     'partner_id_x',
     'payments',
     'planned_expiration_date_x',
     'posted_date_x',
     'sector_x',
     'status_x',
     'tags_x',
     'terms_disbursal_amount',
     'terms_disbursal_currency',
     'terms_disbursal_date',
     'terms_loan_amount',
     'terms_local_payments',
     'terms_loss_liability_currency_exchange',
     'terms_loss_liability_currency_exchange_coverage_rate',
     'terms_loss_liability_nonpayment',
     'terms_repayment_interval',
     'terms_repayment_term',
     'terms_scheduled_payments',
     'themes_x',
     'translator_byline',
     'translator_image',
     'use_x',
     'video_id_x',
     'video_thumbnailImageId_x',
     'video_title_x']
loans_select = loans_complete[selected_cols]

# Rename columns
loans_select = loans_select.rename(columns={'activity_x': 'activity',
                                             'basket_amount_x': 'basket_amount',
                                             'bonus_credit_eligibility_x': 'bonus_credit_eligibility',
                                             'currency_exchange_loss_amount_x': 'currency_exchange_loss_amount',
                                             'description_languages_x': 'description_languages',
                                             'funded_amount_x': 'funded_amount',
                                             'image_id_x': 'image_id',
                                             'image_template_id_x': 'image_template_id',
                                             'lender_count_x': 'lender_count',
                                             'loan_amount_x': 'loan_amount',
                                             'location_country_code_x': 'location_country_code',
                                             'location_country_x': 'location_country',
                                             'location_geo_level_x': 'location_geo_level',
                                             'location_geo_pairs_x': 'location_geo_pairs',
                                             'location_geo_type_x': 'location_geo_type',
                                             'location_town_x': 'location_town',
                                             'name_x': 'name',
                                             'partner_id_x': 'partner_id',
                                             'planned_expiration_date_x': 'planned_expiration_date',
                                             'posted_date_x': 'posted_date',
                                             'sector_x': 'sector',
                                             'status_x': 'status',
                                             'tags_x': 'tags',
                                             'themes_x': 'themes',
                                             'use_x': 'use',
                                             'video_id_x': 'video_id',
                                             'video_thumbnailImageId_x': 'video_thumbnailImageId',
                                             'video_title_x': 'video_title',
                                            'borrower_count': 'borrower_count',
                                             'borrowers': 'borrowers',
                                             'description_texts_en': 'description_texts_en',
                                             'description_texts_es': 'description_texts_es',
                                             'description_texts_fr': 'description_texts_fr',
                                             'description_texts_pt': 'description_texts_pt',
                                             'funded_date': 'funded_date',
                                             'id': 'id',
                                             'journal_totals_bulkEntries': 'journal_totals_bulkEntries',
                                             'journal_totals_entries': 'journal_totals_entries',
                                             'payments': 'payments',
                                             'terms_disbursal_amount': 'terms_disbursal_amount',
                                             'terms_disbursal_currency': 'terms_disbursal_currency',
                                             'terms_disbursal_date': 'terms_disbursal_date',
                                             'terms_loan_amount': 'terms_loan_amount',
                                             'terms_local_payments': 'terms_local_payments',
                                             'terms_loss_liability_currency_exchange': 'terms_loss_liability_currency_exchange',
                                             'terms_loss_liability_currency_exchange_coverage_rate': 'terms_loss_liability_currency_exchange_coverage_rate',
                                             'terms_loss_liability_nonpayment': 'terms_loss_liability_nonpayment',
                                             'terms_repayment_interval': 'terms_repayment_interval',
                                             'terms_repayment_term': 'terms_repayment_term',
                                             'terms_scheduled_payments': 'terms_scheduled_payments',
                                             'translator_byline': 'translator_byline',
                                             'translator_image': 'translator_image'})


loans_select.tail(n=2)
# Out:
#    activity  basket_amount  bonus_credit_eligibility  borrower_count  \
# 18   Retail            NaN                      True              17
# 19   Retail            NaN                      True              22
#
#                                             borrowers  \
# 18  [{'first_name': 'Aissata', 'last_name': '', 'g...
# 19  [{'first_name': 'Awa', 'last_name': '', 'gende...
#
#     currency_exchange_loss_amount description_languages  \
# 18                            NaN              [fr, en]
# 19                            NaN              [fr, en]
#
#                                  description_texts_en description_texts_es  \
# 18  This group is part of a Banc Villageois and ha...                  NaN
# 19  This group consists of 22 women who all live i...                  NaN
#
#                                  description_texts_fr     ...       \
# 18  Ce groupe est né d'un Banc Villageois et est c...     ...
# 19  Ce groupe est composé de 22 femmes qui partage...     ...
#
#    terms_repayment_interval  terms_repayment_term terms_scheduled_payments  \
# 18           At end of term                     8                       []
# 19           At end of term                     8                       []
#
#     themes  translator_byline  translator_image  \
# 18     NaN                NaN               NaN
# 19     NaN     Sophie Narayan         1284174.0
#
#                                       use  video_id  video_thumbnailImageId  \
# 18  to buy fabrics and incense to resell.       NaN                     NaN
# 19  to buy shoes and women's accessories.       NaN                     NaN
#
#     video_title
# 18          NaN
# 19          NaN
#
# [2 rows x 52 columns]

# %%
loans_select.columns.tolist()
# Out:
# ['id_number',
#  'loan_amount',
#  'lender_count',
#  'status',
#  'funded_date',
#  'funded_amount',
#  'repayment_term',
#  'location_country_code',
#  'sector',
#  'description',
#  'use']

# %% [markdown]
# -----
#
# Let's save our data!

# %%
path = ''
loans_select.to_csv(path+'loans_full_africa.csv',
                   index=False)

# %% [markdown]
# Not used
# -----

# %% [markdown]
# We will also pull data about Kiva's partners, who are the intermediaries between Kiva and end recipients for the majority of loans made.

# %%
# data_path = '~/intro_to_machine_learning/data'
# df=pd.read_csv(data_path+'/loans_details.csv', low_memory=False)
# df.head()

# %%
# df=df[df['partner_id'].notnull()]
# df['partner_id']=df['partner_id'].astype(int).astype(str)
# partner_id=df['partner_id'].unique().tolist()

# %%
# d = r.get('https://api.kivaws.org/v1/partners/322.json?app_id=org.deltanalytics')

# %%
# d.headers

# %%
# d.json();

# %%
# def extract_loan_partners(partner_ids):
#     loan_partner_details=pd.DataFrame()
#     for n in partner_ids:
#         d = r.get('https://api.kivaws.org/v1/partners/'+n+'.json?app_id=org.deltanalytics')
#         data = json.loads(d.text)
#         partners=json_normalize(data['partners'])
#         loan_partner_details=loan_partner_details.append(partners, ignore_index=True)
    
#     return loan_partner_details

# %%
# loan_partner_details=extract_loan_partners(partner_id)

# %%
# loan_partner_details.to_csv('~/intro_to_machine_learning/data/loans_partner_details.csv')

# %% [markdown]
# ## Pulling each loan's lender details
#
# Now that we have selected a subset of loans to focus in on, we want to pull all of the lenders of these loans. We do so here by first creating a list of the loans we are interested in.

# %%
# # loan_ids = df['id'].astype(int).astype(str)
# loan_ids = loan_ids.unique().tolist()
# loan_ids[0:5]

# %% [markdown]
# Here we define a function that will extract details of every lender who has contributed to a single loan, and then loop it over the list of loans that we created in the previous step:

# %%
# def extract_loan_lenders(loan_ids):
#     loan_lenders_details=pd.DataFrame()
#     for n in loan_ids:
#         d = r.get('https://api.kivaws.org/v1/loans/'+n+'/lenders.json?app_id=org.deltanalytics')
#         data = json.loads(d.text)
#         if len(data['lenders']) != 0:
#             lenders=json_normalize(data['lenders'])
#         else: lenders = pd.DataFrame()
#         lenders['loan_id'] = n
#         loan_lenders_details = loan_lenders_details.append(lenders, ignore_index=True)

#     return loan_lenders_details

# %%
# loan_lenders_details = extract_loan_lenders(loan_ids)

# %% [markdown]
# We then write the output to a data frame. Let's take a look at what we've got!

# %%
# loan_lenders_details.head(100)

# %%
# loan_lenders_details.to_csv('~/intro_to_machine_learning/data/loans_lenders_details.csv')
